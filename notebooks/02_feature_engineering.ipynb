# %% [markdown]
# # Feature Engineering
# I added new columns that the model can use:
# - daily and weekly returns
# - volatility
# - technical indicators: RSI, SMA, MACD
# These features will help the model decide Buy, Hold, or Sell.

# %%
import pandas as pd
import ta

# %%
# Load raw data
df = pd.read_csv("C:\\Users\\Convenience\\Downloads\\CRYPTO\\crypto-classifier\\data\\raw\\BTCUSDT.csv")

# %%
# Returns
df["return_1d"] = df["close"].pct_change()
df["return_7d"] = df["close"].pct_change(7)

# %%
# Volatility
df["volatility_7d"] = df["close"].rolling(7).std()

# %%
# Technical indicators
df["rsi"] = ta.momentum.RSIIndicator(df["close"]).rsi()
df["sma_20"] = df["close"].rolling(20).mean()
df["sma_50"] = df["close"].rolling(50).mean()
df["sma_200"] = df["close"].rolling(200).mean()
df["macd"] = ta.trend.MACD(df["close"]).macd()

# %%
# Drop rows with NaN
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 801 entries, 199 to 999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   open_time           801 non-null    object
#  1   open                801 non-null    float64
#  2   high                801 non-null    float64
#  3   low                 801 non-null    float64
#  4   close               801 non-null    float64
#  5   volume              801 non-null    float64
#  6   close_time          801 non-null    int64
#  7   quote_asset_volume  801 non-null    float64
#  8   num_trades          801 non-null    int64
#  9   taker_base_volume   801 non-null    float64
#  10  taker_quote_volume  801 non-null    float64
#  11  ignore              801 non-null    int64
#  12  return_1d           801 non-null    float64
#  13  return_7d           801 non-null    float64
#  14  volatility_7d       801 non-null    float64
#  15  rsi                 801 non-null    float64
#  16  sma_20              801 non-null    float64
#  17  sma_50              801 non-null    float64
#  18  sma_200             801 non-null    float64
#  19  macd                801 non-null    float64
# dtypes: float64(16), int64(3), object(1)
# memory usage: 131.4+ KB

# %%
# Save feature CSV
df.to_csv("C:\\Users\\Convenience\\Downloads\\CRYPTO\\crypto-classifier\\data\\processed\\BTCUSDT_features.csv", index=False)
print("Feature-engineered data saved!")
# Out:
# Feature-engineered data saved!

# %%
df.head()
# Out:
#       open_time      open      high       low     close       volume  \
# 199  2023-09-15  26522.73  26888.00  26224.00  26600.00  26227.29369
# 200  2023-09-16  26599.99  26777.00  26445.00  26559.67  13960.93351
# 201  2023-09-17  26559.67  26623.25  26399.00  26527.51  12998.10277
# 202  2023-09-18  26527.50  27409.00  26377.35  26762.51  43000.43256
# 203  2023-09-19  26762.50  27483.57  26667.79  27210.26  36190.52187
#
#         close_time  quote_asset_volume  num_trades  taker_base_volume  \
# 199  1694822399999        6.952033e+08      654094        12600.39115
# 200  1694908799999        3.708899e+08      526416         6508.91352
# 201  1694995199999        3.447037e+08      476775         6359.89459
# 202  1695081599999        1.158780e+09      938705        21551.71605
# 203  1695167999999        9.815393e+08      898076        17851.15558
#
#      taker_quote_volume  ignore  return_1d  return_7d  volatility_7d  \
# 199        3.340459e+08       0   0.002913   0.026611     490.419472
# 200        1.729268e+08       0  -0.001516   0.025406     527.213662
# 201        1.686756e+08       0  -0.001211   0.026542     533.383288
# 202        5.809125e+08       0   0.008859   0.063586     307.013676
# 203        4.840613e+08       0   0.016730   0.053025     302.373358
#
#            rsi      sma_20      sma_50      sma_200        macd
# 199  51.809650  26122.9395  27407.6106  27676.06480 -297.767044
# 200  51.297010  26145.8345  27352.5212  27693.15530 -241.089637
# 201  50.864804  26166.2100  27296.0134  27707.64800 -196.502272
# 202  53.920059  26118.5185  27245.6418  27724.13395 -140.583370
# 203  59.134034  26114.0320  27205.2020  27748.41355  -59.452226
